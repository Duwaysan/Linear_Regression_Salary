# %% [markdown]
# <a href="https://colab.research.google.com/github/Duwaysan/Linear_Regression_Salary/blob/main/Regression_exercise_Salary_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv('/content/drive/MyDrive/Datasets/Salary_Data.csv')
df.sample(5)
# Out:
#       Age  Gender Education Level                 Job Title  \
# 140  28.0    Male      Bachelor's   Junior Business Analyst
# 260   NaN     NaN             NaN                       NaN
# 346  35.0  Female      Bachelor's  Senior Marketing Analyst
# 246  49.0  Female        Master's     Director of Marketing
# 3    36.0  Female      Bachelor's           Sales Associate
#
#      Years of Experience    Salary
# 140                  2.0   40000.0
# 260                  NaN       NaN
# 346                  8.0   85000.0
# 246                 21.0  180000.0
# 3                    7.0   60000.0

# %%
df.shape
# Out:
# (375, 6)

# %%
df_nulls = df.isnull().any(axis=1)
df[df_nulls]
# Out:
#      Age Gender Education Level Job Title  Years of Experience  Salary
# 172  NaN    NaN             NaN       NaN                  NaN     NaN
# 260  NaN    NaN             NaN       NaN                  NaN     NaN

# %%
df.drop([172,260], inplace=True) #dropping rows since they all NaN

# %%
df.duplicated().sum() #no need to drop duplicated because people can have same job same info same salary.
# Out:
# 49

# %%
df.isna().sum()
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# dtype: int64

# %%
df.head()
#df.drop(['Gender','Education Level','Job Title'], axis=1, inplace=True)
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
#from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.compose import ColumnTransformer

# %%
num = ['Age','Years of Experience']
cat = ['Gender','Education Level','Job Title']

# %%
num_transformer = Pipeline(steps=[
    ('scaler', StandardScaler())
])
cat_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])
col_transformer = ColumnTransformer(
    transformers=[
    ('num', num_transformer, num),
    ('cat', cat_transformer, cat)
])

# %%
final_pipeline = Pipeline(steps=[
    ('col_transformer', col_transformer),
    ('model', LinearRegression())
])

x_train, x_test, y_train, y_test = train_test_split(df.drop('Salary', axis=1), df['Salary'], random_state=42)
final_pipeline.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('col_transformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Age',
#                                                    'Years of Experience']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['Gender', 'Education Level',
#                                                    'Job Title'])])),
#                 ('model', LinearRegression())])

# %%
y_pred = final_pipeline.predict(x_test)
y_pred[:5]
# Out:
# array([179977.20054897, 100170.75671708, 120894.50047865, 100000.00100045,
#        131741.80691066])

# %%
 from sklearn.metrics import r2_score
 score = r2_score(y_test, y_pred)
 score
# Out:
# 0.8233300349023558
